# %% [markdown]
# Regresion Lineal

# %%
# Step 1 : import library
import pandas as pd

# %%
# Step 2 : import data
salary = pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/Salary%20Data.csv')

# %%
salary.head(10)
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525
# 5               2.2   39891
# 6               2.5   48266
# 7               2.9   56642
# 8               3.0   60150
# 9               3.2   54445

# %%
print(salary.columns)
# Out:
# Index(['Experience Years', 'Salary'], dtype='object')

# %%
X = salary[['Experience Years']]  # feature
y = salary['Salary']             # target

# %%
# Step 4 : train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.7, random_state=2529)

# %%
# verificar las dimensiones de los conjuntos de entrenamiento y prueba
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((28, 1), (12, 1), (28,), (12,))

# %%
# Step 5 : select model
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# Paso 6: entrenar o ajustar el modelo
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt
plt.scatter(X_train, y_train, color='blue', label='Training data')
plt.scatter(X_test, y_test, color='green', label='Test data')
plt.plot(X_test, y_pred, color='red', linewidth=2, label='Predicted line')
plt.title('Linear Regression: Salary vs Experience')
plt.xlabel('Experience Years')
plt.ylabel('Salary')
plt.legend()
plt.show()

# %%
print("Intercepto (β0):", model.intercept_)
print("Pendiente (β1):", model.coef_[0])
# Out:
# Intercepto (β0): 26596.961311068262
# Pendiente (β1): 9405.616632335526

# %%
# Paso 7: hacer predicciones con el modelo
y_pred = model.predict(X_test)

# %%
# Puntos de los datos originales (training)
plt.plot(X_train, y_train, "b.", label="Datos de entrenamiento")

# Línea de la recta ajustada
y_train_pred = model.predict(X_train)
plt.plot(X_train, y_train_pred, "g-", label="Recta ajustada")

# Cruces rojas para las predicciones sobre test
plt.plot(X_test, y_pred, "rx", label="Predicciones (test)")

# Etiquetas
plt.xlabel("Años de experiencia")
plt.ylabel("Salario")
plt.title("Regresión Lineal: Salario vs Experiencia")
plt.legend()
plt.show()

# %%
# Step 8 : exactitud del modelo
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

print("MAE (Error absoluto medio):", mae)
print("MAPE (Error porcentual medio):", mape)
print("MSE (Error cuadrático medio):", mse)
# Out:
# MAE (Error absoluto medio): 4005.9263101681768
# MAPE (Error porcentual medio): 0.06384602996141632
# MSE (Error cuadrático medio): 24141421.671440993

# %%
mae = mean_absolute_error(y_test, y_pred)
print("MAE:", mae)
# Out:
# MAE: 4005.9263101681768

# %%
mape = mean_absolute_percentage_error(y_test, y_pred)
print("MAPE:", mape)
precision = 1 - mape
print("Precisión aproximada:", precision)
# Out:
# MAPE: 0.06384602996141632
# Precisión aproximada: 0.9361539700385837

# %%
mse = mean_squared_error(y_test, y_pred)
print("MSE:", mse)
# Out:
# MSE: 24141421.671440993
